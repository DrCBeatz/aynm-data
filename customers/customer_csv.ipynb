# %%
import pandas as pd

# %%
input_file = "draw5.csv"
output_file = "draw5_output.csv"

# %%
df = pd.read_csv(input_file)
df
# Out:
#                  Name                           Email           Phone
# 0      Beau Whitfield           beauknows32@gmail.com    613-355-2375
# 1      Gage Whitfield     gagewhitfield9009@gmail.com    705-975-2471
# 2        Kent Swirsky              kswirsky@gmail.com    613-213-4835
# 3       Garrith Rowan          garrith.rm@hotmail.com    905 259 9565
# 4           Elle Sadi             ellesadi@icloud.com      6046719483
# 5   Terry Fitzpatrick           ter.fitzpat@gmail.com    613-863-4864
# 6          Wendy Bell        calvin.bell@sympatico.ca    613-349-2651
# 7       Julie Running    juliedawnrunning@hotmail.com    613-803-7932
# 8        Brent Hordry        brenthordry@sympatico.ca   (613)498-4164
# 9         Talan Young           dtalanyoung@gmail.com    704-492-9635
# 10     Richard Ridell  richard_riddell123@hotmail.com    613 213 1807
# 11       Adam Running     alamrunning1982@Hotmail.com    613 803 6600
# 12      Brie Brereton         briebrereton@gmail.comn    613 349 6218
# 13          Bob Clark         atomicpaddler@gmail.com    613 363 5482
# 14         Fran Boyle             franboyle@Gmail.com    613-345-2155
# 15      Glenys Davies       cakesplusmailbox@yahoo.ca    613-803-9882
# 16     Gordon Andrews           gordonandrews@live.ca    343-264-9025
# 17      Larry Lalonde       lannylalonde102@gmail.com    905-317-6448
# 18    Jackie Dagenais       Jackieedagenais@gmail.com    613-348-3816
# 19   Linda Rightmeyer       lindarightmeyer@gmail.com     105464 0737
# 20  Hillary Gerritsen           hillgerr02@icloud.com    613-803-9562
# 21    Nelda Robertson                neldar@telus.net    403-598-6802
# 22         Paul Noche           jphache1961@gmail.com    613-925-2333
# 23   Danielle Laurier     laurierdanielle55@gmail.com  (613) 407-7680
# 24                Kev           Scotsontop.@gmail.com      6472154107
# 25        Julie Daxon              jkaydee8@gmail.com    613-532-7596
# 26            Jenny H          edgleyharley@gmail.com    613-803-7751
# 27               Kirk      chefintheharbour@gmail.com    613 498 8942
# 28         Dawn Pedro            drateman@outlook.com    613 213 3523
# 29    Ainsleey Worden              ainsleey@gmail.com    613-498-4890
# 30   Gregory Shingler                 gregodb37@gmail           (613)
# 31       Reina Dejong            reinalea04@gmail.com    613-349-7276

# %%
template = pd.read_csv('customers_export.csv')
template.columns
# Out:
# Index(['Customer ID', 'First Name', 'Last Name', 'Email',
#        'Accepts Email Marketing', 'Company', 'Address1', 'Address2', 'City',
#        'Province', 'Province Code', 'Country', 'Country Code', 'Zip', 'Phone',
#        'Accepts SMS Marketing', 'Total Spent', 'Total Orders', 'Tags', 'Note',
#        'Tax Exempt'],
#       dtype='object')

# %%
# Splot 'Name' column into 'First Name' and 'Last Name' columns

name_df = df['Name'].str.split(' ', expand=True)
df['First Name'] = name_df[0]
df['Last Name'] = name_df[1]
df.head()
# Out:
#              Name                        Email         Phone First Name  \
# 0  Beau Whitfield        beauknows32@gmail.com  613-355-2375       Beau
# 1  Gage Whitfield  gagewhitfield9009@gmail.com  705-975-2471       Gage
# 2    Kent Swirsky           kswirsky@gmail.com  613-213-4835       Kent
# 3   Garrith Rowan       garrith.rm@hotmail.com  905 259 9565    Garrith
# 4       Elle Sadi          ellesadi@icloud.com    6046719483       Elle
#
#    Last Name
# 0  Whitfield
# 1  Whitfield
# 2    Swirsky
# 3      Rowan
# 4       Sadi

# %%
# Add to email list

df['Accepts Email Marketing'] = 'yes'
df.head()
# Out:
#              Name                        Email         Phone First Name  \
# 0  Beau Whitfield        beauknows32@gmail.com  613-355-2375       Beau
# 1  Gage Whitfield  gagewhitfield9009@gmail.com  705-975-2471       Gage
# 2    Kent Swirsky           kswirsky@gmail.com  613-213-4835       Kent
# 3   Garrith Rowan       garrith.rm@hotmail.com  905 259 9565    Garrith
# 4       Elle Sadi          ellesadi@icloud.com    6046719483       Elle
#
#    Last Name Accepts Email Marketing
# 0  Whitfield                     yes
# 1  Whitfield                     yes
# 2    Swirsky                     yes
# 3      Rowan                     yes
# 4       Sadi                     yes

# %%
df['Tags']='local'
df.head()
# Out:
#              Name                        Email         Phone First Name  \
# 0  Beau Whitfield        beauknows32@gmail.com  613-355-2375       Beau
# 1  Gage Whitfield  gagewhitfield9009@gmail.com  705-975-2471       Gage
# 2    Kent Swirsky           kswirsky@gmail.com  613-213-4835       Kent
# 3   Garrith Rowan       garrith.rm@hotmail.com  905 259 9565    Garrith
# 4       Elle Sadi          ellesadi@icloud.com    6046719483       Elle
#
#    Last Name Accepts Email Marketing   Tags
# 0  Whitfield                     yes  local
# 1  Whitfield                     yes  local
# 2    Swirsky                     yes  local
# 3      Rowan                     yes  local
# 4       Sadi                     yes  local

# %%
# Remove 'Name' column

df = df.drop(columns=['Name'])
df.head()
# Out:
#                          Email         Phone First Name  Last Name  \
# 0        beauknows32@gmail.com  613-355-2375       Beau  Whitfield
# 1  gagewhitfield9009@gmail.com  705-975-2471       Gage  Whitfield
# 2           kswirsky@gmail.com  613-213-4835       Kent    Swirsky
# 3       garrith.rm@hotmail.com  905 259 9565    Garrith      Rowan
# 4          ellesadi@icloud.com    6046719483       Elle       Sadi
#
#   Accepts Email Marketing   Tags
# 0                     yes  local
# 1                     yes  local
# 2                     yes  local
# 3                     yes  local
# 4                     yes  local

# %%
# Save file

df.to_csv(output_file, index=False)
